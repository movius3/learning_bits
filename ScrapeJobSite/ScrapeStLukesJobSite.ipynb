# %%
from requests_html import HTMLSession

s = HTMLSession()

url = f'https://careers-slhs.icims.com/jobs/search?ss=1&searchCategory=23299'

r = s.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36'})

print(r.text)

# temp = r.html.find('span#wob_tm', first=True).text
# unit = r.html.find('div.vk_bk.wob-unit span.wob_t', first=True).text
# conditions = r.html.find('div.VQF4g', first=True).find('span#wob_dc', first=True).text

# print (query, temp, unit, conditions)
# Out:
# <!DOCTYPE html><html  lang="en-us" prefix=""  class="grunticon"><head id=""  class=""><base href="https://c-6853-20210107-www-stlukesonline-org.i.icims.com/about-st-lukes/">       <base href="https://c-6853-20210107-www-stlukesonline-org.i.icims.com/about-st-lukes/">       <style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}</style>       <!-- META DATA -->                           <link rel="stylesheet" href="/assets/icons/icons.data.svg.css" media="all">       <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-CCT28"></script><script type="text/javascript" async="" src="//siteimproveanalytics.com/js/siteanalyze_69080.js"></script><script async="" src="//rum-static.pingdom.net/prum.min.js"></script><script src="/assets/scripts/util/sharebear.js"></script>     <!--[if IE]>       <meta http-equiv="cleartype" content="on" />       <!
# ...
